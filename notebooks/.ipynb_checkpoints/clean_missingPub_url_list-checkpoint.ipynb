# %%
import pandas as pd
import requests
import os 
import numpy as np
os.chdir('/Users/jmccarty/GitHub/urban_bipv_annotated_bib')


# url = r'http://www.aesc-inc.com/download/Pruitt_PV.pdf'

# print()

# %%
path = os.path.join(os.getcwd(),'data','manual_edits','missingPubs_urls.csv')
df = pd.read_csv(path,index_col='Lens ID')


def check_url(url):
    print(url)
    return requests.get(url, stream=True).status_code

# df['status'] = df.apply(lambda x: check_url(x['External URL']),axis=1)


df["status"] = np.vectorize(check_url) (df['External URL'])
# Out:
# https://www.persee.fr/doc/sgeol_0302-2684_1990_act_86_1_2127
# http://ui.adsabs.harvard.edu/abs/1995STIN...9528396K/abstract
# http://ieeexplore.ieee.org/iel4/5262/14261/00654339.pdf
# https://inis.iaea.org/Search/search.aspx?orig_q=RN:30021177
# http://www.osti.gov/scitech/biblio/20030574-world-largest-photovoltaic-hotel-roof-project-case-study-mauna-lani-bay-hotel-powerguard-reg_sign-system
# http://www.osti.gov/scitech/biblio/20030595-technique-monitoring-predicting-annual-performance-building-integrated-photovoltaic-system
# http://www.osti.gov/scitech/biblio/20030603
# http://www.osti.gov/scitech/biblio/5838484-building-integrated-pv-commercial-industry
# http://ieeexplore.ieee.org/iel5/7320/19792/00916204.pdf
# https://www.narcis.nl/publication/RecordID/oai%3Apure.tue.nl%3Apublications%2Fc537e68c-612b-4272-9e6f-2c449d947a98
# http://www.aesc-inc.com/download/Pruitt_PV.pdf
# https://udspace.udel.edu/handle/19716/1087
# ...
